# %%
# !pip install pandas xlrd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 KB 2.4 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !ls /usr/src/app/misc/besecke/excel/
# Out:
#  LIST_OF_MEASURING_POINTS_Large_2.xls  'LIST_OF_MEASURING_POINTS _Mid.xls'
#  LIST_OF_MEASURING_POINTS_Large.xls     LIST_OF_MEASURING_POINTS_small.xls

# %%
# !python3 /usr/src/app/misc/besecke/batch_processor.py --input=excel/LIST_OF_MEASURING_POINTS_Large_2.xls --output=outputs
# Out:
# ...
# WAGO PLC Configuration Processor
# ...
# Input:  excel/LIST_OF_MEASURING_POINTS_Large_2.xls
# Output: outputs
# ...
#
#
# ...
# WAGO PLC Configuration Extractor
# ...
#
# INFO: Reading IO-Boxen sheet from LIST_OF_MEASURING_POINTS_Large_2.xls...
# INFO: Found 81 rows in IO-Boxen sheet
# INFO: Added PLC: IO020 (172.16.46.020) - Type: 750-8210/025-000
# INFO: Added PLC: IO021 (172.16.46.021) - Type: 750-8210/025-000
# INFO: Added PLC: IO024 (172.16.46.024) - Type: 750-8210
# INFO: Added PLC: IO025 (172.16.46.025) - Type: 750-8210
# INFO: Added PLC: IO032 (172.16.46.032) - Type: 750-8210
# INFO: Added PLC: IO033 (172.16.46.033) - Type: 750-8210
# INFO: Added PLC: IO035 (172.16.46.035) - Type: 750-8210
# INFO: Added PLC: IO036 (172.16.46.036) - Type: 750-8210
# INFO: Added PLC: IO038 (172.16.46.038) - Type: 750-8210
# INFO: Added PLC: IO041 (172.16.46.041) - Type: 750-8210
# INFO: Added PLC: IO052 (172.16.46.052) - Type: 750-8210
# INFO: Added PLC: IO053 (172.16.46.053) - Type: 750-8210
# ...

# %%
# !ls  /usr/src/app/misc/besecke/outputs
# Out:
# PLC_IO020_config.json  PLC_IO112_config.json  PLC_IO215_config.json
# PLC_IO021_config.json  PLC_IO113_config.json  PLC_IO216_config.json
# PLC_IO024_config.json  PLC_IO114_config.json  PLC_IO217_config.json
# PLC_IO025_config.json  PLC_IO115_config.json  PLC_IO218_config.json
# PLC_IO032_config.json  PLC_IO116_config.json  PLC_IO219_config.json
# PLC_IO033_config.json  PLC_IO117_config.json  PLC_IO220_config.json
# PLC_IO035_config.json  PLC_IO132_config.json  PLC_IO221_config.json
# PLC_IO036_config.json  PLC_IO133_config.json  PLC_IO222_config.json
# PLC_IO038_config.json  PLC_IO134_config.json  PLC_IO223_config.json
# PLC_IO041_config.json  PLC_IO135_config.json  PLC_IO224_config.json
# PLC_IO052_config.json  PLC_IO136_config.json  PLC_IO225_config.json
# PLC_IO053_config.json  PLC_IO138_config.json  PLC_IO228_config.json
# PLC_IO054_config.json  PLC_IO151_config.json  PLC_IO229_config.json
# PLC_IO071_config.json  PLC_IO152_config.json  PLC_IO230_config.json
# ...

# %%
# !python codesys_import_example.py --input=/usr/src/app/misc/besecke/outputs
# Out:
# INFO: Standalone mode - file generation only
#
# ...
# CODESYS IronPython Integration - Variable List Generator
# ...
# Input Directory: /usr/src/app/misc/besecke/outputs
# Output Directory: /usr/src/app/misc/besecke/outputs
# Found 78 PLC configuration(s)
# Processing all PLCs...
#
# Processing PLC: IO020
# Source: PLC_IO020_config.json
#
# ...
# PLC Configuration: IO020
# ...
# Type:          750-8210/025-000
# IP Address:    172.16.46.020
# Location:      VI S 0
# IO Box:        36141063
# ----------------------------------------------------------------------
# Modules:       4
# Signals:       669
#   - Inputs:    7
#   - Outputs:   1
# ----------------------------------------------------------------------
# Generated:     2025-10-28T08:28:58.505380
# Source File:   LIST_OF_MEASURING_POINTS_Large_2.xls
# ...
#
# Module Summary:
# ----------------------------------------------------------------------
#   750-432: 3 signals (3 I)
#   750-461: 4 signals (4 I)
#   750-515: 1 signals (1 O)
# ...
